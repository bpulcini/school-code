# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,12))
counts = [45328, 38170, 35591, 32363, 28861]
for x in counts:
    yerr = sqrt(counts)
voltage = [30, 40, 50, 70, 100]
plt.plot(voltage, counts)
plt.plot(voltage, counts, 'bo')
plt.errorbar(voltage, counts, yerr)
print yerr
# Out:
# [ 212.90373411  195.37144111  188.65577118  179.89719286  169.88525539]
